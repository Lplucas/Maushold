# %%
# Importa a função do seu bot.py
from bot import _get_status_emoji

# Agora podemos chamar a função direto e ver o resultado colorido!
resultado_fogo = _get_status_emoji(current_price=100.0, best_deal=40.0, historical_low=40.0)
print("Foguinho 🔥 ->", resultado_fogo)

resultado_bom = _get_status_emoji(current_price=100.0, best_deal=50.0, historical_low=20.0)
print("Desconto Bom ✅ ->", resultado_bom)

resultado_ruim = _get_status_emoji(current_price=100.0, best_deal=90.0, historical_low=50.0)
print("Sem Desconto ❌ ->", resultado_ruim)
# Out:
# Foguinho 🔥 -> 🔥
# Desconto Bom ✅ -> ✅
# Sem Desconto ❌ -> ❌
